# %%
from lib import plot_image_signal

# %%
img_path = "C:\\parzival\\test\\hp115-c-v-m-p-f-e-n-t-i-w-e-r\\d-265b-025_04.png"
plot_image_signal(img_path)

# %%
img_path = "C:\\parzival\\test\\A-hp115-hp115-i-g-a-r-z-i-p060111-n-t-e\\d-262b-031_02.png"
plot_image_signal(img_path)
