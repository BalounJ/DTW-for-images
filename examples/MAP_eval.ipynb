# %% [markdown]
# # Vyhodnocení MAP
# Pro vyhodnocení je použita metrika Mean Average Precision a kvůli rychlosti je použit algoritmus z modulu cdtw. Vyhodnocení probíhá na testovací sadě Parzival Database [1].
#
# ## Postup
# Pro jednotlivá slova sady je vyhodnocena Average Precision. Pokud má slovo pouze jednoho zástupce je přeskočeno. Jinak je jako dotaz vybrán náhodný obrázek odpovídající slovu a ten je porovnán se všemi obrázky v sadě. Mean Average Precision je potom průměr Average Precision jednotlivých dotazů.
#
# ## Výsledky
# Bylo dosaženo 37,7 % MAP pro dotaz podle vzoru (viz výstup, kde jsou vidět i Average Precision jednotlivých dotazů).
#
# [1] Fischer, A. et al. Lexicon-free handwritten word spotting using character
# HMMs. Pattern Recognition Letters. 2012, 33, 7, s. 934 – 942. ISSN
# 0167-8655.

# %%
from eval import eval_MAP_QbE
set_path = "C:\\parzival\\test"
eval_MAP_QbE(set_path)
# Out:
# a-b: 0.04631578947368421
# a-b-e-r: 0.9166666666666666
# a-l: 0.6616162696895044
# a-l-hp115: 0.627766066615162
# a-l-hp115-o: 1.0
# a-l-hp115-v-hp115: 0.125
# a-l-hp115-v-s: 1.0
# a-l-l-e: 0.8711111111111111
# a-l-l-e-n: 0.21666666666666667
# a-l-l-e-r: 1.0
# a-l-r-e-hp115-t: 0.5006747638326585
# a-m-e: 0.0007944520689506481
# a-n: 0.771919177704814
# a-n-c-h-e-r: 0.3333333333333333
# a-n-d-e-r: 0.5033131239405189
# a-n-d-e-r-hp115: 1.0
# a-n-d-e-r-n: 1.0
# a-n-d-r: 0.8541666666666666
# a-n-e: 0.3319716987450825
# A-n-f-o-r-t-a-s: 1.0
# a-n-t-l-v-z-z-e: 0.002053388090349076
# a-n-z: 0.0055248618784530384
# a-r-t: 0.024677571698566554
# A-r-t-v-hp115: 0.5
# A-r-t-v-s: 0.7710092038926017
# a-v-e-n-t-i-v-r-e: 0.10856472255435985
# a-z: 0.2361111111111111
# b-a-n-t: 0.0008116883116883117
# B-a-r-hs111117-c-h: 1.0
# B-a-r-hs111118-c-h: 0.07142857142857142
# b-a-r-v-c-h: 0.000999000999000999
# b-a-t: 0.11918485740299514
# b-a-z: 0.12992803504380473
# b-e-c-h-a-n-t: 0.2
# ...
