# %% [markdown]
# # Vyhledávání podle vzoru

# %%
from dtw import dtw, dtw_basic, dtw_fast
from lib import find_images_plot_n

# %% [markdown]
# ## Nalezení nejbližších obrázků slov pomocí Dynamic Time Warping

# %%
find_images_plot_n(6, "C:\\parzival\\test\\a-b-e-r\\d-143a-011_06.png", "C:\\parzival\\test", dtw_basic)

# %% [markdown]
# ## Nalezení nejbližších obrázků slov pomocí Fast Dynamic Time Warping

# %%
find_images_plot_n(6, "C:\\parzival\\test\\a-b-e-r\\d-143a-011_06.png", "C:\\parzival\\test", dtw_fast, 20)

# %% [markdown]
# ## Nalezení nejbližších obrázků slov pomocí modulu cdtw

# %%
find_images_plot_n(6, "C:\\parzival\\test\\a-b-e-r\\d-143a-011_06.png", "C:\\parzival\\test", dtw)
